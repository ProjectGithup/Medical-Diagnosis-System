# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import pickle

# %%
# Load the diabetes dataset
diabetes_data = pd.read_csv('datasets/diabetes_data.csv')

# %%
# Display basic information about the dataset
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
diabetes_data.shape
# Out:
# (768, 9)

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes_data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# Splitting features and target variable
X = diabetes_data.drop(columns='Outcome', axis=1)
Y = diabetes_data['Outcome']

#

# %%
# Normalize the feature variables
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Splitting the Data into Training and Test Sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)
print("Train/Test Shapes:", X.shape, X_train.shape, X_test.shape)
# Out:
# Train/Test Shapes: (768, 8) (614, 8) (154, 8)

# %%
# Model Training
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Model Evaluation
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training Data:', training_data_accuracy)
# Out:
# Accuracy on Training Data: 0.7850162866449512

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test Data:', test_data_accuracy)
# Out:
# Accuracy on Test Data: 0.7597402597402597

# %%
# Making a Single Prediction
input_data = (5,116,74,0,0,25.6,0.201,30)  # Example input values
input_data_as_numpy_array = np.asarray(input_data).reshape(1, -1)
prediction = model.predict(input_data_as_numpy_array)
print("Prediction:", prediction)
if prediction[0] == 0:
    print('The Person does not have Diabetes')
else:
    print('The Person has Diabetes')
# Out:
# Prediction: [1]
# The Person has Diabetes

# %%
# Save the model
filename = 'diabetes_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# Load the saved model
loaded_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
# Print feature names
print("Feature Columns:", diabetes_data.columns.tolist())
print("Sklearn Version:", sklearn.__version__)
# Out:
# Feature Columns: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
# Sklearn Version: 1.5.0

# %%
# %pip install streamlit-option-menu
# Out:
# Requirement already satisfied: streamlit-option-menu in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (0.4.0)
# Requirement already satisfied: streamlit>=1.36 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit-option-menu) (1.38.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (10.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from streamlit>=1.36->streamlit-option-menu) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (4.22.0)
# Requirement already satisfied: toolz in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.12.1)
# Requirement already satisfied: colorama in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->streamlit>=1.36->streamlit-option-menu) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.36->streamlit-option-menu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.36->streamlit-option-menu) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from pandas<3,>=1.3.0->streamlit>=1.36->streamlit-option-menu) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit-option-menu) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit-option-menu) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit-option-menu) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.36->streamlit-option-menu) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\diksh\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=1.36->streamlit-option-menu) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\diksh\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\diksh\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~treamlit (c:\Users\diksh\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
